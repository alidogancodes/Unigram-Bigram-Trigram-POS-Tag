# %%
import re
import unicodedata
import nltk
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt

# %%
f = open("TUA_Tubitak.txt", encoding="utf8")
df=f.read()

# %%
def basic_clean(text):
  """
  A simple function to clean up the data. All the words that
  are not designated as a stop word is then lemmatized after
  encoding and basic regex parsing are performed.
  """
  wnl = nltk.stem.WordNetLemmatizer()
  stopwords = nltk.corpus.stopwords.words('turkish') 
  words = re.sub(r'[^\w\s]', '', text).split()
  return [wnl.lemmatize(word) for word in words if word not in stopwords]

# %%
words = basic_clean(df)

# %%
unigrams=nltk.ngrams(words,1)
unigramsFrequency=Counter(unigrams)
valuesOfUnigrams=list(unigramsFrequency.values())
unigramlist=list(unigramsFrequency)

for x in range(0,len(unigramlist)):
    if(valuesOfUnigrams[x]>2):
        print(unigramlist[x],"is used",valuesOfUnigrams[x],"times")
# Out:
# ('gözlem',) is used 5 times
# ('ilk',) is used 4 times
# ('yılları',) is used 3 times
# ('arasında',) is used 3 times
# ('uzay',) is used 5 times
# ('BİLSAT',) is used 4 times
# ('uydu',) is used 11 times
# ('olan',) is used 3 times
# ('yılında',) is used 3 times
# ('test',) is used 3 times
# ('birlikte',) is used 3 times
# ('bir',) is used 5 times
# ('sahip',) is used 3 times
# ('uydusu',) is used 8 times
# ('yer',) is used 4 times
# ('m',) is used 4 times
# ('çözünürlüklü',) is used 4 times
# ('olarak',) is used 3 times
# ('projesi',) is used 3 times
# ('kapsamında',) is used 3 times
# ('TÜBİTAK',) is used 5 times
# ('UZAY',) is used 3 times
# ('yerli',) is used 3 times
# ('tarihçesi',) is used 3 times
# ('üretilen',) is used 3 times
# ('RASAT',) is used 4 times
# ('Türk',) is used 3 times
# ('sistem',) is used 3 times
# ('GÖKTÜRK',) is used 4 times
# ('2',) is used 4 times

# %%
bigrams=nltk.ngrams(words,2)
bigramsFrequency=Counter(bigrams)
valuesOfBigrams=list(bigramsFrequency.values())
bigramlist=list(bigramsFrequency)

for x in range(0,len(bigramlist)):
    if(valuesOfBigrams[x]>2):
        print(bigramlist[x],"is used",valuesOfBigrams[x],"times")
# Out:
# ('yılları', 'arasında') is used 3 times
# ('yer', 'gözlem') is used 3 times
# ('gözlem', 'uydusu') is used 3 times
# ('TÜBİTAK', 'UZAY') is used 3 times
# ('uzay', 'tarihçesi') is used 3 times
# ('GÖKTÜRK', '2') is used 4 times

# %%
threegrams1 = nltk.ngrams(words,3)
threegramsFrequency1 = Counter(threegrams1)
valuesofThreegrams1 = list(threegramsFrequency1.values())
threegramlist1 = list(threegramsFrequency1)

for x in range(0, len(threegramlist1)):
    if(valuesofThreegrams1[x] > 1):
        print(threegramlist1[x], " is used ", valuesofThreegrams1[x], " times")
# Out:
# ('yer', 'gözlem', 'uydusu')  is used  3  times
# ('gözlem', 'uydusu', 'olan')  is used  2  times
# ('Gerçek', 'Zamanlı', 'Görüntü')  is used  2  times
# ('Zamanlı', 'Görüntü', 'İşleme')  is used  2  times
# ('GÖKTÜRK', '2', 'uydusu')  is used  2  times

# %%
f = open("Wiktionaryİsim.txt", encoding="utf8")
df2=f.read()

# %%
words2 = basic_clean(df2)

# %%
unigrams=nltk.ngrams(words2,1)
unigramsFrequency=Counter(unigrams)
valuesOfUnigrams=list(unigramsFrequency.values())
unigramlist=list(unigramsFrequency)

for x in range(0,len(unigramlist)):
    if(valuesOfUnigrams[x]>4):
        print(unigramlist[x],"is used",valuesOfUnigrams[x],"times")

# %%
bigrams=nltk.ngrams(words2,2)
bigramsFrequency=Counter(bigrams)
valuesOfBigrams=list(bigramsFrequency.values())
bigramlist=list(bigramsFrequency)

for x in range(0,len(bigramlist)):
    if(valuesOfBigrams[x]>2):
        print(bigramlist[x],"is used",valuesOfBigrams[x],"times")

# %%
threegrams1 = nltk.ngrams(words2,3)
threegramsFrequency1 = Counter(threegrams1)
valuesofThreegrams1 = list(threegramsFrequency1.values())
threegramlist1 = list(threegramsFrequency1)

for x in range(0, len(threegramlist1)):
    if(valuesofThreegrams1[x] > 1):
        print(threegramlist1[x], " is used ", valuesofThreegrams1[x], " times")
    else: print("no matches")
# Out:
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches
# no matches

# %%
 nltk.pos_tag(words)
# Out:
# [('Yer', 'NNP'),
#  ('gözlem', 'NN'),
#  ('uyduları', 'JJ'),
#  ('geliştirme', 'NN'),
#  ('çalışmalarının', 'NNP'),
#  ('ilk', 'NN'),
#  ('adımları', 'NN'),
#  ('1999', 'CD'),
#  ('yılına', 'NN'),
#  ('kadar', 'NN'),
#  ('uzanmaktadır', 'JJ'),
#  ('2000', 'CD'),
#  ('yılından', 'NN'),
#  ('itibaren', 'NNS'),
#  ('çalışmalar', 'JJ'),
#  ('hızlanmış', 'VBD'),
#  ('20012003', 'CD'),
#  ('yılları', 'NN'),
#  ('arasında', 'NN'),
#  ('Devlet', 'NNP'),
#  ('Planlama', 'NNP'),
#  ('Teşkilatından', 'NNP'),
#  ('sağlanan', 'NN'),
#  ('destekle', 'NN'),
#  ('teknoloji', 'NN'),
#  ('transferi', 'NN'),
#  ('yöntemiyle', 'JJ'),
#  ('Türkiyenin', 'NNP'),
#  ('uzay', 'NN'),
#  ('serüveni', 'NN'),
#  ('başlamış', 'NN'),
#  ('BİLSAT', 'NNP'),
#  ('Uydusu', 'NNP'),
#  ('yapılmıştır', 'NNP'),
#  ('Uydunun', 'NNP'),
#  ('yapımında', 'NNP'),
#  ('İngiliz', 'NNP'),
#  ('uydu', 'JJ'),
#  ('teknolojileri', 'NN'),
#  ('şirketi', 'NNP'),
#  ('olan', 'NN'),
#  ('SSTL', 'NNP'),
#  ('Surrey', 'NNP'),
#  ('Satellite', 'NNP'),
#  ('Technology', 'NNP'),
#  ('LimitedSurrey', 'NNP'),
#  ('işbirliği', 'JJ'),
#  ('yapılmıştır', 'NN'),
#  ('Bu', 'NNP'),
#  ('kapsamda', 'NN'),
#  ('2001', 'CD'),
#  ('yılında', 'NN'),
#  ('sekiz', 'NN'),
#  ('araştırmacı', 'NN'),
#  ('uydu', 'JJ'),
#  ('yapım', 'NN'),
#  ('sürecini', 'NN'),
#  ('öğrenmek', 'NNP'),
#  ('bağımsız', 'NN'),
#  ('uydu', 'JJ'),
#  ('yapabilme', 'NN'),
#  ('yeteneği', 'NN'),
#  ('kazanmak', 'NN'),
#  ('İngiltereye', 'NNP'),
#  ('gönderilmiştir', 'NN'),
#  ('Uydu', 'NNP'),
#  ('teknolojilerinin', 'NN'),
#  ('çeşitli', 'NNP'),
#  ('alanları', 'NN'),
#  ('ilgili', 'NN'),
#  ('master', 'NN'),
#  ('yapmaya', 'NN'),
#  ('gidenler', 'NN'),
#  ('üretim', 'JJ'),
#  ('test', 'NN'),
#  ('tasarım', 'NN'),
#  ('gidenlerle', 'NN'),
#  ('birlikte', 'VBD'),
#  ('20', 'CD'),
#  ('civarında', 'NN'),
#  ('araştırmacı', 'NN'),
#  ('uydu', 'JJ'),
#  ('teknolojileri', 'NN'),
#  ('konusunda', 'NN'),
#  ('önemli', 'NNP'),
#  ('bir', 'NN'),
#  ('birikime', 'NN'),
#  ('sahip', 'NN'),
#  ('oldular', 'JJ'),
#  ('Ayrıca', 'NNP'),
#  ('BİLSAT', 'NNP'),
#  ('uydusu', 'JJ'),
#  ('yapılırken', 'NN'),
#  ('işin', 'NN'),
#  ('iyi', 'NN'),
#  ('öğrenilebilmesi', 'NNP'),
#  ('mühendislik', 'NN'),
#  ('modeli', 'NN'),
#  ('sayılabilecek', 'NN'),
#  ('bir', 'NN'),
#  ('uydu', 'JJ'),
#  ('yapıldı', 'NN'),
#  ('Türkiyenin', 'NNP'),
#  ('ilk', 'NN'),
#  ('optik', 'NN'),
#  ('uzaktan', 'JJ'),
#  ('algılama', 'NN'),
#  ('yer', 'NN'),
#  ('gözlem', 'NN'),
#  ('uydusu', 'JJ'),
#  ('olan', 'NN'),
#  ('BİLSAT', 'NNP'),
#  ('12', 'CD'),
#  ('m', 'NN'),
#  ('çözünürlüklü', 'NNP'),
#  ('olarak', 'VBZ'),
#  ('geliştirilmiş', 'JJ'),
#  ('yörüngede', 'NN'),
#  ('başarıyla', 'NN'),
#  ('çalıştırılmıştır', 'NNP'),
#  ('BİLSAT', 'NNP'),
#  ('projesi', 'NN'),
#  ('kapsamında', 'NN'),
#  ('TÜBİTAK', 'NNP'),
#  ('UZAY', 'NNP'),
#  ('tesislerinde', 'NN'),
#  ('Yer', 'NNP'),
#  ('İstasyonu', 'NNP'),
#  ('uydu', 'JJ'),
#  ('üretimtest', 'NNP'),
#  ('laboratuvarları', 'NN'),
#  ('kurulmuş', 'NN'),
#  ('yerli', 'NN'),
#  ('imkânlarla', 'NN'),
#  ('Çok', 'NNP'),
#  ('Bantlı', 'NNP'),
#  ('Kamera', 'NNP'),
#  ('ÇOBAN', 'NNP'),
#  ('Gerçek', 'NNP'),
#  ('Zamanlı', 'NNP'),
#  ('Görüntü', 'NNP'),
#  ('İşleme', 'NNP'),
#  ('kartı', 'NNP'),
#  ('GEZGİN', 'NNP'),
#  ('tasarlanmış', 'NN'),
#  ('uzay', 'JJ'),
#  ('tarihçesi', 'NN'),
#  ('kazandırılmıştır', 'NN'),
#  ('Bu', 'NNP'),
#  ('ekipmanlar', 'JJ'),
#  ('Türkiyede', 'NNP'),
#  ('tasarlanan', 'NN'),
#  ('üretilen', 'NNP'),
#  ('uzay', 'JJ'),
#  ('tarihçesine', 'NN'),
#  ('sahip', 'NN'),
#  ('ilk', 'NN'),
#  ('ürünlerdir', 'NNP'),
#  ('BiLSAT', 'NNP'),
#  ('projesi', 'NN'),
#  ('elde', 'NN'),
#  ('edilen', 'VBN'),
#  ('deneyim', 'JJ'),
#  ('kullanılarak', 'NN'),
#  ('yerli', 'NN'),
#  ('olarak', 'NN'),
#  ('üretilen', 'NNP'),
#  ('ilk', 'NN'),
#  ('yer', 'NN'),
#  ('gözlem', 'NN'),
#  ('uydusu', 'JJ'),
#  ('olan', 'NN'),
#  ('RASAT', 'NNP'),
#  ('20042011', 'CD'),
#  ('yılları', 'NN'),
#  ('arasında', 'NN'),
#  ('yine', 'NN'),
#  ('DPT', 'NNP'),
#  ('desteği', 'NN'),
#  ('geliştirilmiş', 'NN'),
#  ('2011', 'CD'),
#  ('yılında', 'NN'),
#  ('yörüngede', 'CC'),
#  ('devreye', 'NN'),
#  ('alınmıştır', 'VBP'),
#  ('RASAT', 'NNP'),
#  ('75', 'CD'),
#  ('m', 'NN'),
#  ('çözünürlükte', 'NNP'),
#  ('pankromatik', 'VBZ'),
#  ('15', 'CD'),
#  ('m', 'NN'),
#  ('çözünürlükte', 'NNP'),
#  ('RGB', 'NNP'),
#  ('görüntü', 'NN'),
#  ('çekebilmektedir', 'NNP'),
#  ('Proje', 'NNP'),
#  ('kapsamında', 'NNP'),
#  ('uydu', 'JJ'),
#  ('montaj', 'NN'),
#  ('entegrasyon', 'JJ'),
#  ('test', 'NN'),
#  ('laboratuarları', 'NN'),
#  ('büyütülmüş', 'NN'),
#  ('uydu', 'JJ'),
#  ('tasarım', 'NN'),
#  ('üretim', 'JJ'),
#  ('test', 'NN'),
#  ('konularında', 'NN'),
#  ('100den', 'CD'),
#  ('fazla', 'NN'),
#  ('uzman', 'JJ'),
#  ('yetiştirilmiş', 'NN'),
#  ('tamamı', 'NN'),
#  ('ülkemizde', 'NNP'),
#  ('Türk', 'NNP'),
#  ('mühendisler', 'NN'),
#  ('tarafından', 'NN'),
#  ('tasarlanıp', 'NN'),
#  ('üretilen', 'NN'),
#  ('2011', 'CD'),
#  ('yılında', 'NN'),
#  ('fırlatılan', 'NN'),
#  ('milli', 'VBP'),
#  ('gözlem', 'NN'),
#  ('uydumuz', 'JJ'),
#  ('RASAT', 'NNP'),
#  ('Türkiye', 'NNP'),
#  ('uydu', 'JJ'),
#  ('teknolojisinde', 'NN'),
#  ('söz', 'NN'),
#  ('sahibi', 'NN'),
#  ('bir', 'NN'),
#  ('ülke', 'NNP'),
#  ('olmuştur', 'VBZ'),
#  ('Ayrıca', 'NNP'),
#  ('TÜBİTAK', 'NNP'),
#  ('UZAY', 'NNP'),
#  ('bir', 'NN'),
#  ('uydu', 'JJ'),
#  ('projesinin', 'NN'),
#  ('baştan', 'NN'),
#  ('sona', 'NN'),
#  ('gerçekleştirilmesini', 'NN'),
#  ('sağlayacak', 'NN'),
#  ('sistem', 'NN'),
#  ('tasarımı', 'JJ'),
#  ('entegrasyon', 'JJ'),
#  ('yeteneklerine', 'NN'),
#  ('sahip', 'NN'),
#  ('olduğunu', 'JJ'),
#  ('göstermiştir', 'NN'),
#  ('Geliştirilen', 'NNP'),
#  ('Yüksek', 'NNP'),
#  ('Performanslı', 'NNP'),
#  ('Uçuş', 'NNP'),
#  ('Bilgisayarı', 'NNP'),
#  ('BiLGE', 'NNP'),
#  ('100Mbps', 'CD'),
#  ('hızında', 'NN'),
#  ('Xbant', 'NNP'),
#  ('Verici', 'NNP'),
#  ('Gerçek', 'NNP'),
#  ('Zamanlı', 'NNP'),
#  ('Görüntü', 'NNP'),
#  ('İşleme', 'NNP'),
#  ('GEZGİN2', 'NNP'),
#  ('ekipmanları', 'VBZ'),
#  ('yerli', 'JJ'),
#  ('uçuş', 'JJ'),
#  ('yer', 'NN'),
#  ('istasyonu', 'NN'),
#  ('yazılımlarını', 'NN'),
#  ('başarıyla', 'NN'),
#  ('çalıştırılarak', 'NNP'),
#  ('uzay', 'JJ'),
#  ('tarihçesi', 'NN'),
#  ('kazandırmıştır', 'NN'),
#  ('Böylelikle', 'NNP'),
#  ('TÜBİTAK', 'NNP'),
#  ('UZAY', 'NNP'),
#  ('sadece', 'NN'),
#  ('sistem', 'NN'),
#  ('seviyesinde', 'JJ'),
#  ('değil', 'NN'),
#  ('alt', 'NN'),
#  ('sistemler', 'NN'),
#  ('kapsamında', 'NN'),
#  ('yetkinliğini', 'NN'),
#  ('ortaya', 'NN'),
#  ('koymuştur', 'VBD'),
#  ('20072012', 'CD'),
#  ('yılları', 'NN'),
#  ('arasında', 'NN'),
#  ('Türk', 'NNP'),
#  ('Hava', 'NNP'),
#  ('Kuvvetlerinin', 'NNP'),
#  ('yüksek', 'NNP'),
#  ('çözünürlüklü', 'NNP'),
#  ('istihbarat', 'NN'),
#  ('uydusu', 'JJ'),
#  ('ihtiyacını', 'NN'),
#  ('karşılamak', 'NN'),
#  ('TÜBİTAK', 'NNP'),
#  ('UZAYın', 'NNP'),
#  ('ana', 'VBZ'),
#  ('yürütücülüğünde', 'JJ'),
#  ('TUSAŞ', 'NNP'),
#  ('firması', 'NN'),
#  ('birlikte', 'NN'),
#  ('25', 'CD'),
#  ('m', 'NN'),
#  ('çözünürlüklü', 'NNP'),
#  ('GÖKTÜRK', 'NNP'),
#  ('2', 'CD'),
#  ('uydu', 'JJ'),
#  ('projesi', 'NN'),
#  ('gerçekleştirilmiştir', 'NN'),
#  ('TÜBİTAK', 'NNP'),
#  ('UZAYın', 'NNP'),
#  ('RASAT', 'NNP'),
#  ('uydusu', 'JJ'),
#  ('geliştirdiği', 'NN'),
#  ('tarihçe', 'NN'),
#  ('kazandırdığı', 'NN'),
#  ('alt', 'NN'),
#  ('sistemlerin', 'NN'),
#  ('ana', 'NN'),
#  ('sistem', 'NN'),
#  ('olarak', 'JJ'),
#  ('kullanıldığı', 'NN'),
#  ('GÖKTÜRK', 'NNP'),
#  ('2', 'CD'),
#  ('uydusunda', 'JJ'),
#  ('Yakın', 'NNP'),
#  ('Kızıl', 'NNP'),
#  ('Ötesi', 'NNP'),
#  ('SWIR', 'NNP'),
#  ('Kamera', 'NNP'),
#  ('Modülü', 'NNP'),
#  ('KUZGUN', 'NNP'),
#  ('Yönelim', 'NNP'),
#  ('Ekipmanları', 'NNP'),
#  ('Kontrol', 'NNP'),
#  ('Modülü', 'NNP'),
#  ('geliştirilerek', 'NN'),
#  ('uzay', 'JJ'),
#  ('tarihçesi', 'NN'),
#  ('kazanmıştır', 'VBD'),
#  ('18', 'CD'),
#  ('Aralık', 'NNP'),
#  ('2012de', 'CD'),
#  ('fırlatılan', 'NN'),
#  ('GÖKTÜRK', 'NNP'),
#  ('2', 'CD'),
#  ('uydusu', 'JJ'),
#  ('birlikte', 'NN'),
#  ('ülkemiz', 'NNP'),
#  ('kendi', 'NNP'),
#  ('imkânları', 'NN'),
#  ('yüksek', 'NN'),
#  ('çözünürlüklü', 'NNP'),
#  ('yer', 'NN'),
#  ('gözlem', 'NN'),
#  ('uydusu', 'JJ'),
#  ('üretebilen', '$'),
#  ('16', 'CD'),
#  ('ülkeden', 'NNP'),
#  ('birisi', 'NN'),
#  ('olmayı', 'NN'),
#  ('başarmıştır', 'NN'),
#  ('Türk', 'NNP'),
#  ('Hava', 'NNP'),
#  ('Kuvvetleri', 'NNP'),
#  ('tarafından', 'NN'),
#  ('kontrol', 'NN'),
#  ('edilen', 'VBZ'),
#  ('GÖKTÜRK', 'NNP'),
#  ('2', 'CD'),
#  ('uydusu', 'JJ'),
#  ('halen', 'VBN'),
#  ('yörüngesinde', 'NN'),
#  ('başarılı', 'NN'),
#  ('bir', 'NN'),
#  ('şekilde', 'NNP'),
#  ('görevini', 'NN'),
#  ('yerine', 'NN'),
#  ('getirmektedir', 'NN')]

# %%
 nltk.pos_tag(words2)
# Out:
# [('kadın', 'NN'),
#  ('ev', 'NN'),
#  ('göz', 'NN'),
#  ('dünya', 'NN'),
#  ('baş', 'NN'),
#  ('durum', 'NN'),
#  ('yan', 'JJ'),
#  ('hâl', 'NN'),
#  ('su', 'NN'),
#  ('ülke', 'NNP'),
#  ('iç', 'NN'),
#  ('kişi', 'NN'),
#  ('son', 'NN'),
#  ('şekil', 'NNP'),
#  ('yüz', 'NNP'),
#  ('taraf', 'NN'),
#  ('adam', 'NN'),
#  ('s', 'NN'),
#  ('kız', 'NN'),
#  ('para', 'NN'),
#  ('anne', 'NN'),
#  ('baba', 'NN'),
#  ('hayat', 'NN'),
#  ('bilgi', 'VBD'),
#  ('an', 'DT'),
#  ('sonuç', 'JJ'),
#  ('dış', 'NN'),
#  ('ad', 'NN'),
#  ('süre', 'NN'),
#  ('saat', 'NN'),
#  ('yaş', 'NN'),
#  ('sorun', 'VBP'),
#  ('devlet', 'NN'),
#  ('sahip', 'NN'),
#  ('sıra', 'NN'),
#  ('yüzde', 'NN'),
#  ('ay', 'NN'),
#  ('olay', 'NN'),
#  ('söz', 'NN'),
#  ('sistem', 'NN'),
#  ('kapı', 'VBD'),
#  ('kitap', 'JJ'),
#  ('gece', 'NN'),
#  ('alan', 'NN'),
#  ('bugün', 'VBP'),
#  ('dönem', 'NN'),
#  ('arkadaş', 'NN'),
#  ('ürün', 'NNP'),
#  ('aile', 'IN'),
#  ('erkek', 'JJ'),
#  ('güç', 'NN'),
#  ('gerçek', 'NN'),
#  ('ilişki', 'NN'),
#  ('çevre', 'NNP'),
#  ('yaşam', 'NN'),
#  ('halk', 'NN'),
#  ('sokak', 'NN'),
#  ('bey', 'NN'),
#  ('tarih', 'NN'),
#  ('özellik', 'NNP'),
#  ('bölüm', 'NN'),
#  ('akıl', 'NN'),
#  ('anlam', 'NN'),
#  ('banka', 'NN'),
#  ('ayak', 'NN'),
#  ('toplum', 'NN'),
#  ('araç', 'NN'),
#  ('madde', 'NN'),
#  ('tür', 'NN'),
#  ('karar', 'NN'),
#  ('hava', 'NN'),
#  ('sayı', 'NN'),
#  ('grup', 'NN'),
#  ('oda', 'NN'),
#  ('biçim', 'IN'),
#  ('haber', 'NN'),
#  ('Allah', 'NNP'),
#  ('soru', 'NN'),
#  ('arka', 'NN'),
#  ('yazı', 'NN'),
#  ('okul', 'NN'),
#  ('dil', 'NN'),
#  ('şirket', 'NNP'),
#  ('kaynak', 'NN'),
#  ('program', 'NN'),
#  ('hareket', 'NN'),
#  ('renk', 'NN'),
#  ('hak', 'NN'),
#  ('tüketici', 'NN'),
#  ('at', 'IN'),
#  ('site', 'NN'),
#  ('abla', 'NN'),
#  ('çiçek', 'NNP'),
#  ('saygı', 'NN'),
#  ('ücret', 'NNP'),
#  ('yetenek', 'NN'),
#  ('kilo', 'NN'),
#  ('çay', 'NNP'),
#  ('gider', 'NN'),
#  ('laf', 'NN'),
#  ('örgüt', 'NNP'),
#  ('ticaret', 'NN'),
#  ('boyun', 'NN'),
#  ('cihaz', 'NN'),
#  ('denge', 'NN'),
#  ('sırt', 'NN'),
#  ('kahve', 'NN'),
#  ('ka', 'NN'),
#  ('meclis', 'NN'),
#  ('öteki', 'NNP'),
#  ('adres', 'VBZ'),
#  ('paşa', 'JJ'),
#  ('sıcaklık', 'NN'),
#  ('güven', 'NN'),
#  ('marka', 'NN'),
#  ('yaprak', 'NN'),
#  ('yarar', 'NN'),
#  ('gönül', 'NN'),
#  ('hayal', 'NN'),
#  ('şarap', 'NNP'),
#  ('altın', 'VBZ'),
#  ('vitamin', 'FW'),
#  ('ek', 'FW'),
#  ('yumurta', 'FW'),
#  ('eylem', 'FW'),
#  ('kesim', 'FW'),
#  ('kriz', 'FW'),
#  ('birim', 'NN')]
